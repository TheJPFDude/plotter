# %%
#!/usr/bin/python
# %matplotlib notebook

import pandas as pd
import numpy as np
import matplotlib

from matplotlib import pyplot as plt

from aeri_tools.io.dmv.radiance import get_complex_radiance_from_rnc
from aeri_tools.processing.interferogram import get_interferogram_from_spectrum

data = pd.DataFrame()

for i in range(1, 19):
    if i != 12:
        if i < 10:
            fileName = '16020%sB1.CXS' % (i,)
        else:
            fileName = '1602%sB1.CXS' % (i,)
            
        df = get_complex_radiance_from_rnc("/Users/bchoi/Desktop/data/" + fileName)
        data = pd.concat([data, df])
        
interferogram = get_interferogram_from_spectrum(data)

for n in range(0, 200):
    interferogram.iloc[n].plot()

print('done')
# Out:
# <img src="data:image/png;base64,...">
# done

# %%
#!/usr/bin/python
# %matplotlib notebook

import pandas as pd
import numpy as np
import matplotlib

from matplotlib import pyplot as plt

from aeri_tools.io.dmv.radiance import get_complex_radiance_from_rnc
from aeri_tools.processing.interferogram import get_interferogram_from_spectrum

data = pd.DataFrame()
dfs = []

for i in range(1, 30):
    j = i + 5
    if j != 13 and j < 31:
        if j < 10:
            fileName = '15060%sB1.CXS' % (j,)
        else:
            fileName = '1506%sB1.CXS' % (j,)
    elif j - 30 >= 0:
        k = j - 30
        if (k < 3 and k > 5) or (k < 7 and k > 8):
            if k < 10:
                fileName = '15070%sB1.CXS' % (k,)
            else:
                fileName = '1507%sB1.CXS' % (k,)
            
    df = get_complex_radiance_from_rnc("/Users/bchoi/Desktop/data/greensburg_new_data/" + fileName)
    print('radiance ' + str(i))
    dfs.append(df)
    print('appended ' + str(i))
    
del df
print('deleted')
data = pd.concat(dfs)
print('concatenated')        
    
interferogram = get_interferogram_from_spectrum(data)
print('interferogram-ated')

for n in range(0, 200):
    interferogram.iloc[n].plot()

print('done')
# Out:
# radiance 1
# appended 1
# radiance 2
# appended 2
# radiance 3
# appended 3
# radiance 4
# appended 4
# radiance 5
# appended 5
# radiance 6
# appended 6
# radiance 7
# appended 7
# radiance 8
# appended 8
# radiance 9
# appended 9
# radiance 10
# appended 10
# radiance 11
# appended 11
# radiance 12
# appended 12
# radiance 13
# appended 13
# radiance 14
# appended 14
# radiance 15
# appended 15
# radiance 16
# appended 16
# radiance 17
# appended 17
# radiance 18
# appended 18
# radiance 19
# appended 19
# radiance 20
# appended 20
# radiance 21
# appended 21
# radiance 22
# appended 22
# radiance 23
# appended 23
# radiance 24
# appended 24
# radiance 25
# appended 25
# radiance 26
# appended 26
# radiance 27
# appended 27
# radiance 28
# appended 28
# radiance 29
# appended 29
# deleted
# concatenated
# interferogram-ated
# <img src="data:image/png;base64,...">
# done

# %%
#!/usr/bin/python
# %matplotlib notebook

import pandas as pd
import numpy as np
import matplotlib

from matplotlib import pyplot as plt

from aeri_tools.io.dmv.radiance import get_complex_radiance_from_rnc
from aeri_tools.processing.interferogram import get_interferogram_from_spectrum

data = pd.DataFrame()
dfs = []

fileName = '150715B1.CXS'
            
df = get_complex_radiance_from_rnc("/Users/bchoi/Desktop/data/greensburg_new_data/" + fileName)
dfs.append(df)
    
del df
data = pd.concat(dfs)       
    
interferogram = get_interferogram_from_spectrum(data)

for n in range(0, 100):
    interferogram.iloc[n].plot()

print('done')
# Out:
# <img src="data:image/png;base64,...">
# done

# %%
#!/usr/bin/python
# %matplotlib notebook

import pandas as pd
import numpy as np
import matplotlib

from matplotlib import pyplot as plt

from aeri_tools.io.dmv.radiance import get_complex_radiance_from_rnc, get_radiance_from_rnc
from aeri_tools.processing.interferogram import get_interferogram_from_spectrum

data = pd.DataFrame()
dfs = []

fileName = '150620C1.RNC'
            
df = get_radiance_from_rnc("/Users/bchoi/Desktop/data/7_5_16_Data/old/" + fileName)
dfs.append(df)

del df
data= pd.concat(dfs)

interferogram = get_interferogram_from_spectrum(data)

for n in range(0, 1):
    interferogram.iloc[n].plot()
    

data2 = pd.DataFrame()
dfs2 = []

df2 = get_radiance_from_rnc("/Users/bchoi/Desktop/data/7_5_16_Data/new/" + fileName)
dfs2.append(df2)
    
del df2
data2 = pd.concat(dfs2)       
    
interferogram2 = get_interferogram_from_spectrum(data2)

for n in range(0, 100):
    interferogram2.iloc[n].plot()

print('done')
# Out:
# <img src="data:image/png;base64,...">
# done

# %%
#!/usr/bin/python
# %matplotlib notebook

import pandas as pd
import numpy as np
import matplotlib

from matplotlib import pyplot as plt

from aeri_tools.io.dmv.radiance import get_complex_radiance_from_rnc, get_radiance_from_rnc
from aeri_tools.processing.interferogram import get_interferogram_from_spectrum

data = pd.DataFrame()
dfs = []

fileName = '150715C1.RNC'
            
df = get_radiance_from_rnc("/Users/bchoi/Desktop/data/7_5_16_Data/old/" + fileName)
dfs.append(df)

del df
data= pd.concat(dfs)

interferogram = get_interferogram_from_spectrum(data)

for n in range(0, 100):
    interferogram.iloc[n].plot(color='r')
    

data2 = pd.DataFrame()
dfs2 = []

df2 = get_radiance_from_rnc("/Users/bchoi/Desktop/data/7_5_16_Data/new/" + fileName)
dfs2.append(df2)
    
del df2
data2 = pd.concat(dfs2)       
    
interferogram2 = get_interferogram_from_spectrum(data2)

for n in range(0, 100):
    interferogram2.iloc[n].plot(color='y')

print('done')
print('hello friend')
# Out:
# <img src="data:image/png;base64,...">
# done
